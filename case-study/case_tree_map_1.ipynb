# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import jax

# %%
def f(x, y):
    return [x] + y

# %%
x = [5, 6]
y = [[7, 9], [1, 2]]

# %%
f(x, y)
# Out:
# [[5, 6], [7, 9], [1, 2]]

# %%
jax.tree.map(f, x, y)
# Out:
# [[5, 7, 9], [6, 1, 2]]

# %%
y = [[1, 2], [3, 4], [5, 6]]

# %%
f(x,y)
# Out:
# [[5, 6], [1, 2], [3, 4], [5, 6]]

# %%
jax.tree.map(f, x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 jax.tree.map(f, x, y)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/jax/_src/tree.py:61, in map(f, tree, is_leaf, *rest)
#      55 @_add_doc("Alias of :func:`jax.tree_util.tree_map`.")
#      56 @functools.wraps(tree_util.tree_map)
#      57 def map(f: Callable[..., Any],
#      58         tree: Any,
#      59         *rest: Any,
#      60         is_leaf: Callable[[Any], bool] | None = None) -> Any:
# ---> 61   return tree_util.tree_map(f, tree, *rest, is_leaf=is_leaf)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/jax/_src/tree_util.py:319, in tree_map(f, tree, is_leaf, *rest)
#     282 """Maps a multi-input function over pytree args to produce a new pytree.
#     283
#     284 Args:
#    (...)
#     316   - :func:`jax.tree.reduce`
#     317 """
# ...
